# %% [markdown]
# # Install Required Libraries

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\aayus\anaconda3\Lib\site-packages (3.9.1)
# Requirement already satisfied: click in C:\Users\aayus\AppData\Roaming\Python\Python313\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in C:\Users\aayus\anaconda3\Lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\aayus\AppData\Roaming\Python\Python313\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in C:\Users\aayus\AppData\Roaming\Python\Python313\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in C:\Users\aayus\AppData\Roaming\Python\Python313\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\aayus\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\aayus\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aayus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Example Text

# %%
text = "The dog chased the cat because it was very fast."

# %% [markdown]
# # Full Implementation

# %%
import nltk
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize

# %%
# tokenize text
tokens = word_tokenize(text.lower())

print("Tokens:", tokens)

for word in tokens:

    synsets = wordnet.synsets(word)

    if synsets:
        syn = synsets[0]

        print("\nWord:", word)

        # synonyms
        synonyms = [lemma.name() for lemma in syn.lemmas()]
        print("Synonyms:", synonyms)

        # antonyms
        antonyms = []
        for lemma in syn.lemmas():
            if lemma.antonyms():
                antonyms.append(lemma.antonyms()[0].name())

        print("Antonyms:", antonyms)

        # hypernyms
        hypernyms = [h.name().split('.')[0] for h in syn.hypernyms()]
        print("Hypernyms:", hypernyms)
# Out:
# Tokens: ['the', 'dog', 'chased', 'the', 'cat', 'because', 'it', 'was', 'very', 'fast', '.']
#
# Word: dog
# Synonyms: ['dog', 'domestic_dog', 'Canis_familiaris']
# Antonyms: []
# Hypernyms: ['domestic_animal', 'canine']
#
# Word: chased
# Synonyms: ['pursued', 'chased']
# Antonyms: []
# Hypernyms: ['hunted_person']
#
# Word: cat
# Synonyms: ['cat', 'true_cat']
# Antonyms: []
# Hypernyms: ['feline']
#
# Word: it
# Synonyms: ['information_technology', 'IT']
# Antonyms: []
# Hypernyms: ['engineering']
#
# Word: was
# Synonyms: ['Washington', 'Evergreen_State', 'WA']
# Antonyms: []
# Hypernyms: []
#
# Word: very
# Synonyms: ['very']
# Antonyms: []
# Hypernyms: []
#
# Word: fast
# Synonyms: ['fast', 'fasting']
# Antonyms: []
# Hypernyms: ['abstinence']
